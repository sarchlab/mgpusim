# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm

# %%
data = pd.read_csv('r9nano.csv', index_col=0);data
# Out:
#     benchmark    arg      time
# 0    l1v_read  10000  0.010665
# 1    l1v_read  10000  0.010407
# 2    l1v_read  10000  0.010167
# 3    l1v_read  10000  0.010412
# 4    l1v_read  10000  0.010146
# 5    l1v_read  10000  0.010388
# 6    l1v_read  10000  0.010156
# 7    l1v_read  10000  0.010689
# 8    l1v_read  10000  0.010136
# 9    l1v_read  10000  0.010429
# 10   l1v_read  10000  0.010434
# 11   l1v_read  10000  0.010664
# 12   l1v_read  10000  0.010156
# 13   l1v_read  10000  0.010391
# 14   l1v_read  10000  0.010673
# 15   l1v_read  10000  0.010677
# 16   l1v_read  10000  0.010138
# 17   l1v_read  10000  0.010407
# 18   l1v_read  10000  0.010439
# 19   l1v_read  10000  0.010424
# 20   l1v_read  20000  0.010152
# 21   l1v_read  20000  0.010954
# 22   l1v_read  20000  0.010144
# 23   l1v_read  20000  0.010679
# 24   l1v_read  20000  0.010143
# 25   l1v_read  20000  0.010399
# 26   l1v_read  20000  0.010134
# 27   l1v_read  20000  0.010399
# 28   l1v_read  20000  0.010388
# 29   l1v_read  20000  0.010680
# ..        ...    ...       ...
# 150  l1v_read  80000  0.010153
# 151  l1v_read  80000  0.010395
# 152  l1v_read  80000  0.010132
# 153  l1v_read  80000  0.010415
# 154  l1v_read  80000  0.010684
# 155  l1v_read  80000  0.010425
# 156  l1v_read  80000  0.010162
# 157  l1v_read  80000  0.010431
# 158  l1v_read  80000  0.010153
# 159  l1v_read  80000  0.010421
# 160  l1v_read  90000  0.010404
# 161  l1v_read  90000  0.010960
# 162  l1v_read  90000  0.010158
# 163  l1v_read  90000  0.010413
# 164  l1v_read  90000  0.010144
# 165  l1v_read  90000  0.010401
# 166  l1v_read  90000  0.010424
# 167  l1v_read  90000  0.010426
# 168  l1v_read  90000  0.010418
# 169  l1v_read  90000  0.010411
# 170  l1v_read  90000  0.010155
# 171  l1v_read  90000  0.010410
# 172  l1v_read  90000  0.010156
# 173  l1v_read  90000  0.010412
# 174  l1v_read  90000  0.010160
# 175  l1v_read  90000  0.010670
# 176  l1v_read  90000  0.010411
# 177  l1v_read  90000  0.010406
# 178  l1v_read  90000  0.010155
# 179  l1v_read  90000  0.010423
#
# [180 rows x 3 columns]

# %%
grouped = data.groupby('arg')

# %%
grouped.describe()
# Out:
#        time                                                              \
#       count      mean       std       min       25%       50%       75%
# arg
# 10000  20.0  0.010400  0.000199  0.010136  0.010164  0.010410  0.010495
# 20000  20.0  0.010369  0.000266  0.010134  0.010148  0.010390  0.010416
# 30000  20.0  0.010375  0.000153  0.010134  0.010330  0.010416  0.010426
# 40000  20.0  0.010378  0.000177  0.010139  0.010162  0.010417  0.010435
# 50000  20.0  0.010348  0.000166  0.010145  0.010161  0.010409  0.010419
# 60000  20.0  0.010385  0.000172  0.010129  0.010336  0.010409  0.010420
# 70000  20.0  0.010339  0.000153  0.010141  0.010157  0.010415  0.010424
# 80000  20.0  0.010361  0.000184  0.010132  0.010157  0.010404  0.010422
# 90000  20.0  0.010376  0.000197  0.010144  0.010160  0.010410  0.010420
#
#
#             max
# arg
# 10000  0.010689
# 20000  0.010962
# 30000  0.010663
# 40000  0.010673
# 50000  0.010680
# 60000  0.010687
# 70000  0.010681
# 80000  0.010688
# 90000  0.010960

# %%
agg_data = grouped.agg(np.mean)
agg_data = agg_data.reset_index()
agg_data.columns = ['size', 'time']
agg_data
# Out:
#     size      time
# 0  10000  0.010400
# 1  20000  0.010369
# 2  30000  0.010375
# 3  40000  0.010378
# 4  50000  0.010348
# 5  60000  0.010385
# 6  70000  0.010339
# 7  80000  0.010361
# 8  90000  0.010376

# %%
result = sm.ols(formula="time ~ size", data=agg_data).fit()
result.params['size']
# Out:
# -3.096169085833284e-10
